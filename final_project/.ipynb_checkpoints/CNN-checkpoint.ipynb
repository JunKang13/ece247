# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import datetime
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, BatchNormalization, MaxPooling2D, Reshape, LSTM, add, AveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import glorot_uniform, he_uniform
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from utils import *
# Out:
# Device mapping: no known devices.

# %% [markdown]
# ## Data Loading

# %%
X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
print(X_train_valid.shape)
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

y_train_valid -= 769
y_test -= 769

ch_data = X_train_valid[:,0,:]

class_0_ind = np.where(y_train_valid == 0)
ch_data_class_0 = ch_data[class_0_ind]
avg_ch_data_class_0 = np.mean(ch_data_class_0,axis=0)

class_1_ind = np.where(y_train_valid == 1)
ch_data_class_1 = ch_data[class_1_ind]
avg_ch_data_class_1 = np.mean(ch_data_class_1,axis=0)

class_2_ind = np.where(y_train_valid == 2)
ch_data_class_2 = ch_data[class_2_ind]
avg_ch_data_class_2 = np.mean(ch_data_class_2,axis=0)

class_3_ind = np.where(y_train_valid == 3)
ch_data_class_3 = ch_data[class_3_ind]
avg_ch_data_class_3 = np.mean(ch_data_class_3,axis=0)

plt.figure(figsize=(10, 4))
plt.title('EEG Signal of subject 0')
plt.plot(np.arange(1000),avg_ch_data_class_0)
plt.plot(np.arange(1000),avg_ch_data_class_1)
plt.plot(np.arange(1000),avg_ch_data_class_2)
plt.plot(np.arange(1000),avg_ch_data_class_3)
plt.axvline(x=500, label='line at t=500',c='cyan')

plt.legend(["Cue Onset left", "Cue Onset right", "Cue onset foot", "Cue onset tongue"])
# Out:
# (2115, 22, 1000)

# %% [markdown]
# ### Raw Data

# %%
X_train, y_train, X_test, y_test = init_data(subject=None, verbose=True)
ind_valid = np.random.choice(X_train.shape[0], int(0.1 * X_train.shape[0]), replace=False)
ind_train = np.array(list(set(range(X_train.shape[0])).difference(set(ind_valid))))
(x_train_raw, x_valid_raw) = X_train[ind_train], X_train[ind_valid]
(y_train_raw, y_valid_raw) = y_train[ind_train], y_train[ind_valid]
x_train_raw, y_train_raw, x_valid_raw, y_valid_raw, x_test_raw, y_test_raw = load_data(x_train_raw, y_train_raw, x_valid_raw, y_valid_raw, X_test, y_test, verbose=True)
# Out:
# Training data shape: (1904, 1000, 1, 22) Training target shape: (1904, 4)
# Validation data shape: (211, 1000, 1, 22) Validation target shape: (211, 4)
# Testing data shape: (443, 1000, 1, 22) Testing target shape: (443, 4)

# %% [markdown]
# ### Feature Scaling

# %%
x_mean = np.mean(X_train, axis=0)
x_std = np.std(X_train, axis=0)
X_train_fc = X_train - x_mean
X_train_fc /= x_std
X_test_fc = X_test - x_mean
X_test_fc /= x_std
ind_valid = np.random.choice(X_train_fc.shape[0], int(0.1 * X_train.shape[0]), replace=False)
ind_train = np.array(list(set(range(X_train_fc.shape[0])).difference(set(ind_valid))))
(x_train_fc, x_valid_fc) = X_train[ind_train], X_train[ind_valid]
(y_train_fc, y_valid_fc) = y_train[ind_train], y_train[ind_valid]
x_train_fc, y_train_fc, x_valid_fc, y_valid_fc, x_test_fc, y_test_fc = load_data(x_train_fc, y_train_fc, x_valid_fc, y_valid_fc, X_test_fc, y_test, verbose=True)
# Out:
# Training data shape: (1904, 1000, 1, 22) Training target shape: (1904, 4)
# Validation data shape: (211, 1000, 1, 22) Validation target shape: (211, 4)
# Testing data shape: (443, 1000, 1, 22) Testing target shape: (443, 4)

# %% [markdown]
# ### Data Augmentation

# %%
X_train_aug, y_train_aug, X_test_aug, y_test_aug, X_valid_aug, y_valid_aug= preprocess_data(X_train, y_train, X_test, y_test, verbose=True)
x_train_aug, y_train_aug, x_valid_aug, y_valid_aug, x_test_aug, y_test_aug = load_data(X_train_aug, y_train_aug, X_valid_aug, y_valid_aug, X_test_aug, y_test_aug, verbose=True)
# Out:
# Training data shape: (7616, 22, 250) Training target shape: (7616,)
# Testing data shape: (443, 22, 250) Testing target shape: (443,)
# Training data shape: (7616, 250, 1, 22) Training target shape: (7616, 4)
# Validation data shape: (844, 250, 1, 22) Validation target shape: (844, 4)
# Testing data shape: (443, 250, 1, 22) Testing target shape: (443, 4)

# %% [markdown]
# ### Data Windowing

# %%
X_train_window, y_train_window = window_data(X_train, y_train, window_size=800,stride=100, verbose=True)
X_test_window, y_test_window = window_data(X_test, y_test, window_size=800,stride=100, verbose=True)
X_train_window, y_train_window, X_test_window, y_test_window, X_valid_window, y_valid_window= preprocess_data(X_train_window, y_train_window, X_test_window, y_test_window, verbose=True)
x_train_window, y_train_window, x_valid_window, y_valid_window, x_test_window, y_test_window = load_data(X_train_window, y_train_window, X_valid_window, y_valid_window, X_test_window, y_test_window, verbose=True)
# Out:
# Windowed Training data shape: (4230, 22, 800) Windowed Training target shape: (4230,)
# Windowed Training data shape: (886, 22, 800) Windowed Training target shape: (886,)
# Training data shape: (15228, 22, 250) Training target shape: (15228,)
# Testing data shape: (886, 22, 250) Testing target shape: (886,)
# Training data shape: (15228, 250, 1, 22) Training target shape: (15228, 4)
# Validation data shape: (1692, 250, 1, 22) Validation target shape: (1692, 4)
# Testing data shape: (886, 250, 1, 22) Testing target shape: (886, 4)

# %% [markdown]
# ### Data CWT

# %%
X_train, y_train, X_test, y_test = init_data(subject=None)
X_train, y_train, X_test, y_test, X_valid, y_valid = preprocess_data(X_train, y_train, X_test, y_test, verbose=True)

scales = np.arange(1, 7)

X_train_cwt = cwt_transform(X_train, scales, ricker, verbose=True)
X_valid_cwt = cwt_transform(X_valid, scales, ricker, verbose=True)
X_test_cwt = cwt_transform(X_test, scales, ricker, verbose=True)

y_train_cwt = to_categorical(y_train, 4)
y_valid_cwt = to_categorical(y_valid, 4)
y_test_cwt = to_categorical(y_test, 4)

x_train_cwt = np.swapaxes(X_train_cwt, 1, 3)
x_valid_cwt = np.swapaxes(X_valid_cwt, 1, 3)
x_test_cwt = np.swapaxes(X_test_cwt, 1, 3)
# Out:
# Training data shape: (7616, 22, 250) Training target shape: (7616,)
# Testing data shape: (443, 22, 250) Testing target shape: (443,)
# CWT Transformed data shape: (7616, 22, 6, 250)
# CWT Transformed data shape: (844, 22, 6, 250)
# CWT Transformed data shape: (443, 22, 6, 250)

# %% [markdown]
# ## MaxPool_CNN

# %% [markdown]
# ### Sample Architecture (Slight change based on different datasets)

# %%
dropout = 0.55
learning_rate = 0.001
epochs = 50
weight_decay = 0.05

model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(12,1), padding='same', activation='elu', input_shape=(250,1,22), kernel_initializer='glorot_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=64, kernel_size=(12,1), padding='same', activation='elu', kernel_initializer='glorot_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=128, kernel_size=(10,1), padding='same', activation='elu', kernel_initializer='glorot_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=256, kernel_size=(10,1), padding='same', activation='elu', kernel_initializer='glorot_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Flatten())
model.add(Dense(50, activation='elu', kernel_regularizer=l2(weight_decay), bias_regularizer=l2(weight_decay), kernel_initializer='glorot_uniform'))
model.add(Dense(4, activation='softmax', kernel_regularizer=l2(weight_decay), bias_regularizer=l2(weight_decay), kernel_initializer='glorot_uniform'))
            

optimizer = tf.keras.optimizers.Adam(lr=learning_rate)

model.compile(loss='categorical_crossentropy',
                optimizer=optimizer,
                metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 250, 1, 32)        8480
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 84, 1, 32)         0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 84, 1, 32)         128
# _________________________________________________________________
# dropout (Dropout)            (None, 84, 1, 32)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 84, 1, 64)         24640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 28, 1, 64)         0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 1, 64)         256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28, 1, 64)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 1, 128)        82048
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 10, 1, 128)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 10, 1, 128)        512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 10, 1, 128)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 10, 1, 256)        327936
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 1, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 4, 1, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 1, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 50)                51250
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 204
# =================================================================
# Total params: 496,478
# Trainable params: 495,518
# Non-trainable params: 960
# _________________________________________________________________

# %% [markdown]
# ## Train/Test

# %% [markdown]
# ### On Raw Data

# %%
dropout = 0.55
learning_rate = 0.001
epochs = 50
weight_decay = 0.05

model = Sequential()

model.add(Conv2D(filters=25, kernel_size=(12,1), padding='same', activation='elu', input_shape=(1000,1,22), kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=50, kernel_size=(12,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=200, kernel_size=(10,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Flatten())
model.add(Dense(50, activation='elu', kernel_regularizer=l2(weight_decay), bias_regularizer=l2(weight_decay), kernel_initializer='he_uniform'))
model.add(Dense(4, activation='softmax', kernel_regularizer=l2(weight_decay), bias_regularizer=l2(weight_decay), kernel_initializer='he_uniform'))
            
lr_callback = tf.keras.callbacks.ReduceLROnPlateau(patience = 10, factor = 0.1)
optimizer = tf.keras.optimizers.Adam(lr=learning_rate)

model.compile(loss='categorical_crossentropy',
                optimizer=optimizer,
                metrics=['accuracy'])

results = model.fit(x_train_raw,
            y_train_raw,
            batch_size=64,
            epochs=epochs,
            validation_data=(x_valid_raw, y_valid_raw), callbacks=[lr_callback], verbose=1)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('CNN Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('CNN Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.tight_layout()
plt.show()

score = model.evaluate(x_test_raw, y_test_raw, verbose=0)
print(f'Test accuracy:{score[1]}')
# Out:
# Epoch 1/50
# 30/30 [==============================] - 3s 90ms/step - loss: 7.0584 - accuracy: 0.2763 - val_loss: 8.2872 - val_accuracy: 0.2986
# Epoch 2/50
# 30/30 [==============================] - 2s 81ms/step - loss: 5.3769 - accuracy: 0.3220 - val_loss: 4.8461 - val_accuracy: 0.3128
# Epoch 3/50
# 30/30 [==============================] - 2s 80ms/step - loss: 4.2763 - accuracy: 0.3136 - val_loss: 3.7847 - val_accuracy: 0.3270
# Epoch 4/50
# 30/30 [==============================] - 2s 79ms/step - loss: 3.4671 - accuracy: 0.3398 - val_loss: 3.0723 - val_accuracy: 0.3744
# Epoch 45/50
# 30/30 [==============================] - 2s 81ms/step - loss: 1.0340 - accuracy: 0.6465 - val_loss: 1.0872 - val_accuracy: 0.6303
# Epoch 46/50
# 30/30 [==============================] - 2s 82ms/step - loss: 1.0220 - accuracy: 0.6523 - val_loss: 1.1472 - val_accuracy: 0.6019
# Epoch 47/50
# 30/30 [==============================] - 3s 84ms/step - loss: 1.0266 - accuracy: 0.6523 - val_loss: 1.0766 - val_accuracy: 0.6445
# Epoch 48/50
# 30/30 [==============================] - 2s 80ms/step - loss: 1.0036 - accuracy: 0.6686 - val_loss: 1.1446 - val_accuracy: 0.5924
# Epoch 49/50
# 30/30 [==============================] - 2s 81ms/step - loss: 1.0009 - accuracy: 0.6707 - val_loss: 1.0206 - val_accuracy: 0.6540
# Epoch 50/50
# 30/30 [==============================] - 2s 80ms/step - loss: 1.0026 - accuracy: 0.6738 - val_loss: 1.0563 - val_accuracy: 0.6398
# Test accuracy:0.5869074463844299

# %% [markdown]
# ### On Scaled Data

# %%
dropout = 0.55
learning_rate = 0.001
epochs = 50
weight_decay = 0.05

model = Sequential()

model.add(Conv2D(filters=25, kernel_size=(12,1), padding='same', activation='elu', input_shape=(1000,1,22), kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=50, kernel_size=(12,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=200, kernel_size=(10,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Flatten())
model.add(Dense(50, activation='elu', kernel_regularizer=l2(weight_decay), bias_regularizer=l2(weight_decay), kernel_initializer='he_uniform'))
model.add(Dense(4, activation='softmax', kernel_regularizer=l2(weight_decay), bias_regularizer=l2(weight_decay), kernel_initializer='he_uniform'))
            
lr_callback = tf.keras.callbacks.ReduceLROnPlateau(patience = 10, factor = 0.1)
optimizer = tf.keras.optimizers.Adam(lr=learning_rate)

model.compile(loss='categorical_crossentropy',
                optimizer=optimizer,
                metrics=['accuracy'])

results = model.fit(x_train_fc,
            y_train_fc,
            batch_size=64,
            epochs=epochs,
            validation_data=(x_valid_fc, y_valid_fc), callbacks=[lr_callback], verbose=1)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('CNN Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('CNN Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.tight_layout()
plt.show()

score = model.evaluate(x_test_fc, y_test_fc, verbose=0)
print(f'Test accuracy:{score[1]}')
# Out:
# Epoch 1/50
# 30/30 [==============================] - 3s 95ms/step - loss: 7.0112 - accuracy: 0.2652 - val_loss: 6.3281 - val_accuracy: 0.3033
# Epoch 2/50
# 30/30 [==============================] - 2s 79ms/step - loss: 5.4681 - accuracy: 0.2925 - val_loss: 4.9343 - val_accuracy: 0.3128
# Epoch 3/50
# 30/30 [==============================] - 2s 80ms/step - loss: 4.2955 - accuracy: 0.3288 - val_loss: 3.7838 - val_accuracy: 0.3460
# Epoch 4/50
# 30/30 [==============================] - 2s 79ms/step - loss: 3.5110 - accuracy: 0.3519 - val_loss: 3.1351 - val_accuracy: 0.3412
# Epoch 5/50
# 30/30 [==============================] - 2s 79ms/step - loss: 2.9450 - accuracy: 0.3755 - val_loss: 2.7172 - val_accuracy: 0.3791
# Epoch 6/50
# 30/30 [==============================] - 2s 79ms/step - loss: 2.5250 - accuracy: 0.3718 - val_loss: 2.4016 - val_accuracy: 0.3318
# Epoch 7/50
# 30/30 [==============================] - 2s 79ms/step - loss: 2.2229 - accuracy: 0.3776 - val_loss: 2.2358 - val_accuracy: 0.3981
# 30/30 [==============================] - 2s 78ms/step - loss: 1.1906 - accuracy: 0.5604 - val_loss: 1.3258 - val_accuracy: 0.4265
# Epoch 32/50
# 30/30 [==============================] - 2s 77ms/step - loss: 1.1408 - accuracy: 0.5772 - val_loss: 1.3852 - val_accuracy: 0.4976
# Epoch 33/50
# 30/30 [==============================] - 2s 77ms/step - loss: 1.1638 - accuracy: 0.5693 - val_loss: 1.2339 - val_accuracy: 0.5403
# Epoch 34/50
# 30/30 [==============================] - 2s 78ms/step - loss: 1.1346 - accuracy: 0.5987 - val_loss: 1.3117 - val_accuracy: 0.4929
# Epoch 35/50
# 30/30 [==============================] - 2s 78ms/step - loss: 1.1458 - accuracy: 0.5898 - val_loss: 1.2935 - val_accuracy: 0.4787
# Epoch 36/50
# 30/30 [==============================] - 2s 78ms/step - loss: 1.1358 - accuracy: 0.5840 - val_loss: 1.2449 - val_accuracy: 0.5261
# Epoch 37/50
# 30/30 [==============================] - 2s 80ms/step - loss: 1.1080 - accuracy: 0.6108 - val_loss: 1.2021 - val_accuracy: 0.5829
# Epoch 38/50
# 30/30 [==============================] - 2s 79ms/step - loss: 1.1092 - accuracy: 0.5982 - val_loss: 1.1871 - val_accuracy: 0.5924
# Epoch 39/50
# 30/30 [==============================] - 2s 79ms/step - loss: 1.1125 - accuracy: 0.5940 - val_loss: 1.2268 - val_accuracy: 0.5498
# Epoch 40/50
# 30/30 [==============================] - 2s 79ms/step - loss: 1.0962 - accuracy: 0.6161 - val_loss: 1.2031 - val_accuracy: 0.5687
# Epoch 41/50
# 30/30 [==============================] - 2s 78ms/step - loss: 1.0923 - accuracy: 0.6150 - val_loss: 1.2128 - val_accuracy: 0.5450
# Epoch 42/50
# 30/30 [==============================] - 2s 81ms/step - loss: 1.1048 - accuracy: 0.6113 - val_loss: 1.2410 - val_accuracy: 0.5166
# Epoch 43/50
# 30/30 [==============================] - 2s 80ms/step - loss: 1.0837 - accuracy: 0.6329 - val_loss: 1.1854 - val_accuracy: 0.5261
# Epoch 44/50
# 30/30 [==============================] - 2s 80ms/step - loss: 1.0661 - accuracy: 0.6334 - val_loss: 1.1630 - val_accuracy: 0.6303
# Epoch 45/50
# 30/30 [==============================] - 2s 79ms/step - loss: 1.0653 - accuracy: 0.6287 - val_loss: 1.1977 - val_accuracy: 0.5735
# Epoch 46/50
# 30/30 [==============================] - 2s 81ms/step - loss: 1.0479 - accuracy: 0.6429 - val_loss: 1.1634 - val_accuracy: 0.5735
# Epoch 47/50
# 30/30 [==============================] - 2s 80ms/step - loss: 1.0352 - accuracy: 0.6318 - val_loss: 1.2059 - val_accuracy: 0.5735
# Epoch 48/50
# 30/30 [==============================] - 2s 80ms/step - loss: 1.0374 - accuracy: 0.6418 - val_loss: 1.1734 - val_accuracy: 0.5829
# Epoch 49/50
# 30/30 [==============================] - 2s 80ms/step - loss: 1.0183 - accuracy: 0.6602 - val_loss: 1.2347 - val_accuracy: 0.5782
# Epoch 50/50
# 30/30 [==============================] - 2s 80ms/step - loss: 1.0225 - accuracy: 0.6555 - val_loss: 1.1765 - val_accuracy: 0.6019
# Test accuracy:0.2460496574640274

# %% [markdown]
# ### On Aug Data

# %%
dropout = 0.55
learning_rate = 0.0007
epochs = 100
weight_decay = 0.05

model = Sequential()

model.add(Conv2D(filters=25, kernel_size=(12,1), padding='same', activation='elu', input_shape=(250,1,22), kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=50, kernel_size=(12,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=200, kernel_size=(10,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Flatten())
model.add(Dense(50, activation='elu', kernel_regularizer=l2(weight_decay), bias_regularizer=l2(weight_decay), kernel_initializer='he_uniform'))
model.add(Dense(4, activation='softmax', kernel_regularizer=l2(weight_decay), bias_regularizer=l2(weight_decay), kernel_initializer='he_uniform'))
            
lr_callback = tf.keras.callbacks.ReduceLROnPlateau(patience = 10, factor = 0.1)
optimizer = tf.keras.optimizers.Adam(lr=learning_rate)

model.compile(loss='categorical_crossentropy',
                optimizer=optimizer,
                metrics=['accuracy'])

results = model.fit(x_train_aug,
            y_train_aug,
            batch_size=64,
            epochs=epochs,
            validation_data=(x_valid_aug, y_valid_aug), callbacks=[lr_callback], verbose=1)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('CNN Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('CNN Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.tight_layout()
plt.show()

score = model.evaluate(x_test_aug, y_test_aug, verbose=0)
print(f'Test accuracy:{score[1]}')
# Out:
# Epoch 1/100
# 119/119 [==============================] - 3s 26ms/step - loss: 5.6363 - accuracy: 0.2965 - val_loss: 3.9495 - val_accuracy: 0.3531
# Epoch 2/100
# 119/119 [==============================] - 3s 25ms/step - loss: 3.1822 - accuracy: 0.3522 - val_loss: 2.5826 - val_accuracy: 0.2962
# Epoch 3/100
# 119/119 [==============================] - 3s 26ms/step - loss: 2.1436 - accuracy: 0.3906 - val_loss: 1.9443 - val_accuracy: 0.2950
# Epoch 4/100
# 119/119 [==============================] - 3s 25ms/step - loss: 1.6739 - accuracy: 0.4262 - val_loss: 1.5658 - val_accuracy: 0.3803
# Epoch 5/100
# 119/119 [==============================] - 3s 24ms/step - loss: 1.4409 - accuracy: 0.4624 - val_loss: 1.4214 - val_accuracy: 0.3863
# Epoch 6/100
# 119/119 [==============================] - 3s 25ms/step - loss: 1.3155 - accuracy: 0.4858 - val_loss: 1.3019 - val_accuracy: 0.4573
# Epoch 7/100
# 119/119 [==============================] - 3s 25ms/step - loss: 1.2459 - accuracy: 0.5101 - val_loss: 1.2229 - val_accuracy: 0.5000
# Epoch 8/100
# 119/119 [==============================] - 3s 25ms/step - loss: 1.1995 - accuracy: 0.5270 - val_loss: 1.1944 - val_accuracy: 0.5166
# Epoch 9/100
# 119/119 [==============================] - 3s 25ms/step - loss: 1.1538 - accuracy: 0.5494 - val_loss: 1.1659 - val_accuracy: 0.5427
# Epoch 10/100
# 119/119 [==============================] - 3s 25ms/step - loss: 1.1240 - accuracy: 0.5671 - val_loss: 1.1617 - val_accuracy: 0.5486
# Epoch 11/100
# 119/119 [==============================] - 3s 25ms/step - loss: 1.0979 - accuracy: 0.5810 - val_loss: 1.1819 - val_accuracy: 0.5130
# Epoch 12/100
# 119/119 [==============================] - 3s 24ms/step - loss: 1.0698 - accuracy: 0.5927 - val_loss: 1.0586 - val_accuracy: 0.5924
# Epoch 13/100
# 119/119 [==============================] - 3s 24ms/step - loss: 1.0478 - accuracy: 0.6053 - val_loss: 1.0913 - val_accuracy: 0.5841
# Epoch 14/100
# 119/119 [==============================] - 3s 25ms/step - loss: 1.0287 - accuracy: 0.6125 - val_loss: 1.0580 - val_accuracy: 0.5818
# Epoch 15/100
# 119/119 [==============================] - 3s 24ms/step - loss: 1.0215 - accuracy: 0.6163 - val_loss: 1.0619 - val_accuracy: 0.5936
# Epoch 16/100
# 119/119 [==============================] - 3s 25ms/step - loss: 0
100
# 119/119 [==============================] - 3s 23ms/step - loss: 0.4954 - accuracy: 0.8495 - val_loss: 0.7596 - val_accuracy: 0.7536
# Epoch 75/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4876 - accuracy: 0.8487 - val_loss: 0.7541 - val_accuracy: 0.7630
# Epoch 76/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4753 - accuracy: 0.8575 - val_loss: 0.7637 - val_accuracy: 0.7500
# Epoch 77/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4847 - accuracy: 0.8549 - val_loss: 0.7522 - val_accuracy: 0.7500
# Epoch 78/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4836 - accuracy: 0.8541 - val_loss: 0.7659 - val_accuracy: 0.7512
# Epoch 79/100
# 119/119 [==============================] - 3s 23ms/step - loss: 0.4844 - accuracy: 0.8520 - val_loss: 0.7551 - val_accuracy: 0.7524
# Epoch 80/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4787 - accuracy: 0.8603 - val_loss: 0.7486 - val_accuracy: 0.7536
# Epoch 81/100
# 119/119 [==============================] - 3s 23ms/step - loss: 0.4738 - accuracy: 0.8569 - val_loss: 0.7451 - val_accuracy: 0.7524
# Epoch 82/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4877 - accuracy: 0.8489 - val_loss: 0.7605 - val_accuracy: 0.7547
# Epoch 83/100
# 119/119 [==============================] - 3s 23ms/step - loss: 0.4846 - accuracy: 0.8543 - val_loss: 0.7525 - val_accuracy: 0.7547
# Epoch 84/100
# 119/119 [==============================] - 3s 23ms/step - loss: 0.4803 - accuracy: 0.8532 - val_loss: 0.7499 - val_accuracy: 0.7607
# Epoch 85/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4800 - accuracy: 0.8546 - val_loss: 0.7519 - val_accuracy: 0.7607
# Epoch 86/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4754 - accuracy: 0.8560 - val_loss: 0.7510 - val_accuracy: 0.7618
# Epoch 87/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4841 - accuracy: 0.8514 - val_loss: 0.7451 - val_accuracy: 0.7642
# Epoch 88/100
# 119/119 [==============================] - 3s 23ms/step - loss: 0.4779 - accuracy: 0.8546 - val_loss: 0.7566 - val_accuracy: 0.7547
# Epoch 89/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4690 - accuracy: 0.8562 - val_loss: 0.7615 - val_accuracy: 0.7500
# Epoch 90/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4633 - accuracy: 0.8653 - val_loss: 0.7560 - val_accuracy: 0.7595
# Epoch 91/100
# 119/119 [==============================] - 3s 23ms/step - loss: 0.4726 - accuracy: 0.8586 - val_loss: 0.7420 - val_accuracy: 0.7666
# Epoch 92/100
# 119/119 [==============================] - 3s 23ms/step - loss: 0.4691 - accuracy: 0.8585 - val_loss: 0.7465 - val_accuracy: 0.7642
# Epoch 93/100
# 119/119 [==============================] - 3s 25ms/step - loss: 0.4597 - accuracy: 0.8646 - val_loss: 0.7510 - val_accuracy: 0.7713
# Epoch 94/100
# 119/119 [==============================] - 3s 23ms/step - loss: 0.4716 - accuracy: 0.8546 - val_loss: 0.7436 - val_accuracy: 0.7654
# Epoch 95/100
# 119/119 [==============================] - 3s 23ms/step - loss: 0.4631 - accuracy: 0.8606 - val_loss: 0.7430 - val_accuracy: 0.7690
# Epoch 96/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4715 - accuracy: 0.8554 - val_loss: 0.7526 - val_accuracy: 0.7701
# Epoch 97/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4591 - accuracy: 0.8638 - val_loss: 0.7484 - val_accuracy: 0.7654
# Epoch 98/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4666 - accuracy: 0.8604 - val_loss: 0.7390 - val_accuracy: 0.7678
# Epoch 99/100
# 119/119 [==============================] - 3s 24ms/step - loss: 0.4727 - accuracy: 0.8606 - val_loss: 0.7511 - val_accuracy: 0.7678
# Epoch 100/100
# 119/119 [==============================] - 3s 25ms/step - loss: 0.4656 - accuracy: 0.8595 - val_loss: 0.7476 - val_accuracy: 0.7654
# Test accuracy:0.722347617149353

# %% [markdown]
# ### On Windowed Data

# %%
dropout = 0.5
learning_rate = 0.003
epochs = 100
weight_decay = 0.01

model = Sequential()

model.add(Conv2D(filters=25, kernel_size=(12,1), padding='same', activation='elu', input_shape=(250,1,22), kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=50, kernel_size=(12,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Conv2D(filters=150, kernel_size=(10,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
model.add(BatchNormalization())
model.add(Dropout(dropout))



model.add(Flatten())
model.add(Dense(50, activation='elu', kernel_regularizer=l2(weight_decay), bias_regularizer=l2(weight_decay), kernel_initializer='he_uniform'))
model.add(Dense(4, activation='softmax', kernel_regularizer=l2(weight_decay), bias_regularizer=l2(weight_decay), kernel_initializer='he_uniform'))
            
lr_callback = tf.keras.callbacks.ReduceLROnPlateau(patience = 10, factor = 0.1)
optimizer = tf.keras.optimizers.Adam(lr=learning_rate)

model.compile(loss='categorical_crossentropy',
                optimizer=optimizer,
                metrics=['accuracy'])

results = model.fit(x_train_window,
            y_train_window,
            batch_size=64,
            epochs=epochs,
            validation_data=(x_valid_window, y_valid_window), callbacks=[lr_callback], verbose=1)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.title('CNN Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(results.history['accuracy'])
plt.plot(results.history['val_accuracy'])
plt.title('CNN Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.tight_layout()
plt.show()

score = model.evaluate(x_test_window, y_test_window, verbose=0)
print(f'Test accuracy:{score[1]}')
# Out:
# Epoch 1/100
# 238/238 [==============================] - 6s 27ms/step - loss: 2.0019 - accuracy: 0.3265 - val_loss: 1.5278 - val_accuracy: 0.3434
# Epoch 2/100
# 238/238 [==============================] - 6s 24ms/step - loss: 1.3532 - accuracy: 0.4266 - val_loss: 1.2291 - val_accuracy: 0.4598
# Epoch 3/100
# 238/238 [==============================] - 6s 26ms/step - loss: 1.2083 - accuracy: 0.5007 - val_loss: 1.0945 - val_accuracy: 0.5822
# Epoch 4/100
# 238/238 [==============================] - 6s 25ms/step - loss: 1.1021 - accuracy: 0.5594 - val_loss: 1.0561 - val_accuracy: 0.5898
# Epoch 5/100
# 238/238 [==============================] - 6s 23ms/step - loss: 1.0508 - accuracy: 0.5796 - val_loss: 1.0090 - val_accuracy: 0.6058
# Epoch 6/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0.9946 - accuracy: 0.6151 - val_loss: 0.9676 - val_accuracy: 0.6466
# Epoch 7/100
# 238/238 [==============================] - 5s 23ms/step - loss: 0.9484 - accuracy: 0.6398 - val_loss: 0.9800 - val_accuracy: 0.6111
# Epoch 8/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0.9163 - accuracy: 0.6512 - val_loss: 0.8677 - val_accuracy: 0.6874
# Epoch 9/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0.8871 - accuracy: 0.6726 - val_loss: 0.8655 - val_accuracy: 0.7004
# Epoch 10/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0.8662 - accuracy: 0.6799 - val_loss: 0.9354 - val_accuracy: 0.6513
# Epoch 11/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0.8399 - accuracy: 0.6919 - val_loss: 0.8431 - val_accuracy: 0.6939
# Epoch 12/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0.8121 - accuracy: 0.7034 - val_loss: 0.7898 - val_accuracy: 0.7015
# Epoch 13/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0.7944 - accuracy: 0.7152 - val_loss: 0.8287 - val_accuracy: 0.6962
# Epoch 14/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0.7650 - accuracy: 0.7264 - val_loss: 0.7783 - val_accuracy: 0.7252
# Epoch 15/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0.7612 - accuracy: 0.7270 - val_loss: 0.7679 - val_accuracy: 0.7210
# Epoch 16/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0.7404 - accuracy: 0.7423 - val_loss: 0.8457 - val_accuracy: 0.6803
# Epoch 17/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0.7295 - accuracy: 0.7459 - val_loss: 0.8011 - val_accuracy: 0.7376
# Epoch 18/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0.7128 - accuracy: 0.7522 - val_loss: 0.7128 - val_accuracy: 0.7583
# Epoch 19/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0.6943 - accuracy: 0.7579 - val_loss: 0.7158 - val_accuracy: 0.7565
# Epoch 20/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0
100
# 238/238 [==============================] - 6s 26ms/step - loss: 0.3540 - accuracy: 0.8852 - val_loss: 0.4560 - val_accuracy: 0.8428
# Epoch 87/100
# 238/238 [==============================] - 6s 26ms/step - loss: 0.3427 - accuracy: 0.8877 - val_loss: 0.4555 - val_accuracy: 0.8463
# Epoch 88/100
# 238/238 [==============================] - 6s 24ms/step - loss: 0.3396 - accuracy: 0.8905 - val_loss: 0.4534 - val_accuracy: 0.8517
# Epoch 89/100
# 238/238 [==============================] - 6s 25ms/step - loss: 0.3380 - accuracy: 0.8918 - val_loss: 0.4700 - val_accuracy: 0.8392
# Epoch 90/100
# 238/238 [==============================] - 6s 25ms/step - loss: 0.3411 - accuracy: 0.8904 - val_loss: 0.4575 - val_accuracy: 0.8463
# Epoch 91/100
# 238/238 [==============================] - 6s 26ms/step - loss: 0.3438 - accuracy: 0.8867 - val_loss: 0.4503 - val_accuracy: 0.8522
# Epoch 92/100
# 238/238 [==============================] - 6s 25ms/step - loss: 0.3405 - accuracy: 0.8876 - val_loss: 0.4470 - val_accuracy: 0.8475
# Epoch 93/100
# 238/238 [==============================] - 6s 26ms/step - loss: 0.3376 - accuracy: 0.8901 - val_loss: 0.4456 - val_accuracy: 0.8481
# Epoch 94/100
# 238/238 [==============================] - 6s 25ms/step - loss: 0.3352 - accuracy: 0.8897 - val_loss: 0.4417 - val_accuracy: 0.8505
# Epoch 95/100
# 238/238 [==============================] - 6s 26ms/step - loss: 0.3398 - accuracy: 0.8877 - val_loss: 0.4454 - val_accuracy: 0.8475
# Epoch 96/100
# 238/238 [==============================] - 6s 26ms/step - loss: 0.3295 - accuracy: 0.8935 - val_loss: 0.4421 - val_accuracy: 0.8505
# Epoch 97/100
# 238/238 [==============================] - 6s 26ms/step - loss: 0.3365 - accuracy: 0.8907 - val_loss: 0.4417 - val_accuracy: 0.8546
# Epoch 98/100
# 238/238 [==============================] - 6s 26ms/step - loss: 0.3265 - accuracy: 0.8945 - val_loss: 0.4389 - val_accuracy: 0.8528
# Epoch 99/100
# 238/238 [==============================] - 6s 26ms/step - loss: 0.3277 - accuracy: 0.8920 - val_loss: 0.4413 - val_accuracy: 0.8517
# Epoch 100/100
# 238/238 [==============================] - 6s 26ms/step - loss: 0.3337 - accuracy: 0.8907 - val_loss: 0.4415 - val_accuracy: 0.8511
# Test accuracy:0.7054176330566406

# %% [markdown]
# ## Train based on subjects (Use Aug data since better generalization)

# %%
acc_subjects = []
acc_subject_v_all = []
X_train, y_train, X_test, y_test = init_data(subject=None, verbose=False)
X_train_aug, y_train_aug, X_test_aug, y_test_aug, X_valid_aug, y_valid_aug= preprocess_data(X_train, y_train, X_test, y_test, verbose=False)
_, _, _, _, x_test_aug_all, y_test_aug_all = load_data(X_train_aug, y_train_aug, X_valid_aug, y_valid_aug, X_test_aug, y_test_aug, verbose=False)

for i in range(9):
    X_train, y_train, X_test, y_test = init_data(subject=i, verbose=False)
    X_train_aug, y_train_aug, X_test_aug, y_test_aug, X_valid_aug, y_valid_aug= preprocess_data(X_train, y_train, X_test, y_test, verbose=False)
    x_train_aug, y_train_aug, x_valid_aug, y_valid_aug, x_test_aug, y_test_aug = load_data(X_train_aug, y_train_aug, X_valid_aug, y_valid_aug, X_test_aug, y_test_aug, verbose=False)

    dropout = 0.55
    learning_rate = 0.0007
    epochs = 100
    weight_decay = 0.05
    
    model = Sequential()
    
    model.add(Conv2D(filters=25, kernel_size=(12,1), padding='same', activation='elu', input_shape=(250,1,22), kernel_initializer='he_uniform'))
    model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))
    
    model.add(Conv2D(filters=50, kernel_size=(12,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
    model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))
    
    model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
    model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))
    
    model.add(Conv2D(filters=200, kernel_size=(10,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
    model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))
    
    model.add(Flatten())
    model.add(Dense(50, activation='elu', kernel_regularizer=l2(weight_decay), bias_regularizer=l2(weight_decay), kernel_initializer='he_uniform'))
    model.add(Dense(4, activation='softmax', kernel_regularizer=l2(weight_decay), bias_regularizer=l2(weight_decay), kernel_initializer='he_uniform'))

    early_stop = EarlyStopping(monitor='val_loss',
                           patience=10,        
                           verbose=1,         
                           mode='min',         
                           restore_best_weights=True)
    lr_callback = tf.keras.callbacks.ReduceLROnPlateau(patience = 10, factor = 0.1)
    optimizer = tf.keras.optimizers.Adam(lr=learning_rate)
    
    model.compile(loss='categorical_crossentropy',
                    optimizer=optimizer,
                    metrics=['accuracy'])
    
    results = model.fit(x_train_aug,
                y_train_aug,
                batch_size=64,
                epochs=epochs,
                validation_data=(x_valid_aug, y_valid_aug), callbacks=[lr_callback], verbose=0)

    score = model.evaluate(x_test_aug, y_test_aug, verbose=0)
    print(f'Test accuracy for subject {i}: {score[1]}')
    acc_subjects.append(score[1])

    score = model.evaluate(x_test_aug_all, y_test_aug_all, verbose=0)
    print(f'Test accuracy for subject {i} to all data: {score[1]}')
    acc_subject_v_all.append(score[1])

print(acc_subjects)
print(acc_subject_v_all)
# Out:
# Test accuracy for subject 0: 0.6000000238418579
# Test accuracy for subject 0 to all data: 0.43115124106407166
# Test accuracy for subject 1: 0.5199999809265137
# Test accuracy for subject 1 to all data: 0.3995485305786133
# Test accuracy for subject 2: 0.6000000238418579
# Test accuracy for subject 2 to all data: 0.3882618546485901
# Test accuracy for subject 3: 0.6200000047683716
# Test accuracy for subject 3 to all data: 0.41986456513404846
# Test accuracy for subject 4: 0.7659574747085571
# Test accuracy for subject 4 to all data: 0.43792325258255005
# Test accuracy for subject 5: 0.5510203838348389
# Test accuracy for subject 5 to all data: 0.3386004567146301
# Test accuracy for subject 6: 0.699999988079071
# Test accuracy for subject 6 to all data: 0.45598194003105164
# Test accuracy for subject 7: 0.5199999809265137
# Test accuracy for subject 7 to all data: 0.3453724682331085
# Test accuracy for subject 8: 0.7234042286872864
# Test accuracy for subject 8 to all data: 0.32279908657073975
# [0.6000000238418579, 0.5199999809265137, 0.6000000238418579, 0.6200000047683716, 0.7659574747085571, 0.5510203838348389, 0.699999988079071, 0.5199999809265137, 0.7234042286872864]
# [0.43115124106407166, 0.3995485305786133, 0.3882618546485901, 0.41986456513404846, 0.43792325258255005, 0.3386004567146301, 0.45598194003105164, 0.3453724682331085, 0.32279908657073975]

# %%
subjects = [i for i in range(1,10)]

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1) 
bars = plt.bar(subjects, acc_subjects, color='skyblue')
plt.title('Model Accuracy Across 9 Subjects')
plt.xlabel('Subject')
plt.ylabel('Accuracy')
plt.xticks(subjects)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

plt.subplot(1, 2, 2) 
bars = plt.bar(subjects, acc_subject_v_all, color='salmon')
plt.title('Model Accuracy to All Data Across 9 Subjects')
plt.xlabel('Subject')
plt.ylabel('Accuracy')
plt.xticks(subjects)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Train based on timestamps

# %%
acc_timestamps = []

for j in range(100, 1001, 100):
    X_train, y_train, X_test, y_test = init_data(subject=None, verbose=False)
    ind_valid = np.random.choice(X_train.shape[0], int(0.1 * X_train.shape[0]), replace=False)
    ind_train = np.array(list(set(range(X_train.shape[0])).difference(set(ind_valid))))
    (x_train, x_valid) = X_train[ind_train], X_train[ind_valid]
    (y_train, y_valid) = y_train[ind_train], y_train[ind_valid]

    X_train = x_train[:, :, :j]
    X_valid = x_valid[:, :, :j]
    X_test = X_test[:, :, :j]
    X__train_max = np.max(X_train.reshape(X_train.shape[0], X_train.shape[1], -1, 2), axis=3)
    X_test_max = np.max(X_test.reshape(X_test.shape[0], X_test.shape[1], -1, 2), axis=3)
    X_average_train = np.mean(X_train.reshape(X_train.shape[0], X_train.shape[1], -1, 2), axis=3)
    X_average_train = X_average_train + np.random.normal(0.0, 0.5, X_average_train.shape)
    X__valid_max = np.max(X_valid.reshape(X_valid.shape[0], X_valid.shape[1], -1, 2), axis=3)
    X_average_valid = np.mean(X_valid.reshape(X_valid.shape[0], X_valid.shape[1], -1, 2), axis=3)
    X_average_valid = X_average_valid + np.random.normal(0.0, 0.5, X_average_valid.shape)
    total_X_train = np.vstack((X__train_max, X_average_train))
    total_y_train = np.hstack((y_train, y_train))
    total_X_valid = np.vstack((X__valid_max, X_average_valid))
    total_y_valid = np.hstack((y_valid, y_valid))
    for i in range(2):
        X_subsample = X_train[:, :, i::2] + np.random.normal(0.0, 0.5, X_train[:, :, i::2].shape)

        total_X_train = np.vstack((total_X_train, X_subsample))
        total_y_train = np.hstack((total_y_train, y_train))

    for i in range(2):
        X_subsample = X_valid[:, :, i::2] + np.random.normal(0.0, 0.5, X_valid[:, :, i::2].shape)
        total_X_valid = np.vstack((total_X_valid, X_subsample))
        total_y_valid = np.hstack((total_y_valid, y_valid))

    x_train_aug, y_train_aug, x_valid_aug, y_valid_aug, x_test_aug, y_test_aug = load_data(total_X_train, total_y_train, total_X_valid, total_y_valid, X_test_max, y_test, verbose=True)


    dropout = 0.55
    learning_rate = 0.0007
    epochs = 100
    weight_decay = 0.05
    
    model = Sequential()
    
    model.add(Conv2D(filters=25, kernel_size=(12,1), padding='same', activation='elu', input_shape=(x_train_aug.shape[1],1,22), kernel_initializer='he_uniform'))
    model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))
    
    model.add(Conv2D(filters=50, kernel_size=(12,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
    model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))
    
    model.add(Conv2D(filters=100, kernel_size=(10,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
    model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))
    
    model.add(Conv2D(filters=200, kernel_size=(10,1), padding='same', activation='elu', kernel_initializer='he_uniform'))
    model.add(MaxPooling2D(pool_size=(3,1), strides=(3,1), padding='same'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))
    
    model.add(Flatten())
    model.add(Dense(50, activation='elu', kernel_regularizer=l2(weight_decay), bias_regularizer=l2(weight_decay), kernel_initializer='he_uniform'))
    model.add(Dense(4, activation='softmax', kernel_regularizer=l2(weight_decay), bias_regularizer=l2(weight_decay), kernel_initializer='he_uniform'))

    early_stop = EarlyStopping(monitor='val_loss',
                           patience=10,        
                           verbose=1,         
                           mode='min',         
                           restore_best_weights=True)
    lr_callback = tf.keras.callbacks.ReduceLROnPlateau(patience = 10, factor = 0.1)
    optimizer = tf.keras.optimizers.Adam(lr=learning_rate)
    
    model.compile(loss='categorical_crossentropy',
                    optimizer=optimizer,
                    metrics=['accuracy'])
    
    results = model.fit(x_train_aug,
                y_train_aug,
                batch_size=64,
                epochs=epochs,
                validation_data=(x_valid_aug, y_valid_aug), callbacks=[lr_callback], verbose=0)

    score = model.evaluate(x_test_aug, y_test_aug, verbose=0)
    print(f'Test accuracy for timestamp {j}: {score[1]}')
    acc_timestamps.append(score[1])
# Out:
# Training data shape: (7616, 50, 1, 22) Training target shape: (7616, 4)
# Validation data shape: (844, 50, 1, 22) Validation target shape: (844, 4)
# Testing data shape: (443, 50, 1, 22) Testing target shape: (443, 4)
# Test accuracy for timestamp 100: 0.5643340945243835
# Training data shape: (7616, 100, 1, 22) Training target shape: (7616, 4)
# Validation data shape: (844, 100, 1, 22) Validation target shape: (844, 4)
# Testing data shape: (443, 100, 1, 22) Testing target shape: (443, 4)
# Test accuracy for timestamp 200: 0.6501128673553467
# Training data shape: (7616, 150, 1, 22) Training target shape: (7616, 4)
# Validation data shape: (844, 150, 1, 22) Validation target shape: (844, 4)
# Testing data shape: (443, 150, 1, 22) Testing target shape: (443, 4)
# Test accuracy for timestamp 300: 0.7246049642562866
# Training data shape: (7616, 200, 1, 22) Training target shape: (7616, 4)
# Validation data shape: (844, 200, 1, 22) Validation target shape: (844, 4)
# Testing data shape: (443, 200, 1, 22) Testing target shape: (443, 4)
# Test accuracy for timestamp 400: 0.6997742652893066
# Training data shape: (7616, 250, 1, 22) Training target shape: (7616, 4)
# Validation data shape: (844, 250, 1, 22) Validation target shape: (844, 4)
# Testing data shape: (443, 250, 1, 22) Testing target shape: (443, 4)
# Test accuracy for timestamp 500: 0.7110609412193298
# Training data shape: (7616, 300, 1, 22) Training target shape: (7616, 4)
# Validation data shape: (844, 300, 1, 22) Validation target shape: (844, 4)
# Testing data shape: (443, 300, 1, 22) Testing target shape: (443, 4)
# Test accuracy for timestamp 600: 0.722347617149353
# Training data shape: (7616, 350, 1, 22) Training target shape: (7616, 4)
# Validation data shape: (844, 350, 1, 22) Validation target shape: (844, 4)
# Testing data shape: (443, 350, 1, 22) Testing target shape: (443, 4)
# Test accuracy for timestamp 700: 0.7178329825401306
# Training data shape: (7616, 400, 1, 22) Training target shape: (7616, 4)
# Validation data shape: (844, 400, 1, 22) Validation target shape: (844, 4)
# Testing data shape: (443, 400, 1, 22) Testing target shape: (443, 4)
# Test accuracy for timestamp 800: 0.7291196584701538
# Training data shape: (7616, 450, 1, 22) Training target shape: (7616, 4)
# Validation data shape: (844, 450, 1, 22) Validation target shape: (844, 4)
# Testing data shape: (443, 450, 1, 22) Testing target shape: (443, 4)
# Test accuracy for timestamp 900: 0.6884875893592834
# Training data shape: (7616, 500, 1, 22) Training target shape: (7616, 4)
# Validation data shape: (844, 500, 1, 22) Validation target shape: (844, 4)
# Testing data shape: (443, 500, 1, 22) Testing target shape: (443, 4)
# Test accuracy for timestamp 1000: 0.715575635433197

# %%
timestamps = [i for i in range(100, 1001, 100)]
plt.figure(figsize=(10, 6))
plt.plot(timestamps, acc_timestamps, marker='o', linestyle='-', color='b')

plt.title('CNN Accuracy Over Time')
plt.xlabel('Timestamp')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')
